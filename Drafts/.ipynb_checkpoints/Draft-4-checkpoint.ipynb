# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.model_selection import train_test_split
import numpy as np

# =========================
# 1. Load & Utility
# =========================
def load_adbench_data(dataset_path):
    """
    Giả sử file .npz có 'X' và 'y'
    X: (N, d), y: (N,)
    """
    data = np.load(dataset_path)
    X = data['X']
    y = data['y']
    return torch.tensor(X, dtype=torch.float32), torch.tensor(y, dtype=torch.float32)

def evaluate_with_classification_report_and_auc(model, test_loader, device, threshold=0.5):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch).squeeze()  # (B,)
            all_preds.append(y_pred.cpu())
            all_labels.append(y_batch.cpu())

    preds = torch.cat(all_preds).numpy()      # (N_test,)
    labels = torch.cat(all_labels).numpy()    # (N_test,)

    # Chuyển sang nhãn nhị phân
    binary_preds = (preds > threshold).astype(int)

    report = classification_report(labels, binary_preds, target_names=['Class 0', 'Class 1'])
    print(report)

    if len(set(labels)) > 1:
        aucroc = roc_auc_score(labels, preds)
        print(f"AUC-ROC: {aucroc:.4f}")
    else:
        aucroc = None
        print("AUC-ROC: Undefined (only one class present in labels)")
    return report, aucroc

# =========================
# 2. Beta-CVAE
# =========================
class BetaCVAE(nn.Module):
    """
    Beta-CVAE cho bài toán nhị phân:
      - Encoder nhận (x, y)
      - Decoder nhận (z, y)
      - Thêm hệ số beta > 1 cho KL-divergence để khuyến khích latent space 'trải rộng'.
    """
    def __init__(self, input_dim, hidden_dim=128, latent_dim=32, beta=4.0):
        super(BetaCVAE, self).__init__()
        self.input_dim = input_dim
        self.latent_dim = latent_dim
        self.beta = beta  # hệ số "phóng đại" KL

        # Encoder
        self.fc1 = nn.Linear(input_dim + 1, hidden_dim)   # concat y -> +1
        self.fc2_mean = nn.Linear(hidden_dim, latent_dim)
        self.fc2_logvar = nn.Linear(hidden_dim, latent_dim)
        
        # Decoder
        self.fc3 = nn.Linear(latent_dim + 1, hidden_dim)  # concat y -> +1
        self.fc4 = nn.Linear(hidden_dim, input_dim)

    def encode(self, x, y):
        xy = torch.cat([x, y], dim=1)  # (B, input_dim+1)
        h = F.relu(self.fc1(xy))
        mean = self.fc2_mean(h)
        logvar = self.fc2_logvar(h)
        return mean, logvar

    def reparameterize(self, mean, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mean + eps * std

    def decode(self, z, y):
        zy = torch.cat([z, y], dim=1)  # (B, latent_dim+1)
        h = F.relu(self.fc3(zy))
        x_recon = self.fc4(h)
        return x_recon

    def forward(self, x, y):
        mean, logvar = self.encode(x, y)
        z = self.reparameterize(mean, logvar)
        x_recon = self.decode(z, y)
        return x_recon, mean, logvar

def beta_cvae_loss_fn(x, x_recon, mean, logvar, beta=4.0):
    """
    Reconstruction (MSE) + beta * KL-div
    """
    recon_loss = F.mse_loss(x_recon, x, reduction='sum')
    kl_loss    = -0.5 * torch.sum(1 + logvar - mean.pow(2) - logvar.exp())
    return recon_loss + beta * kl_loss

def train_beta_cvae(model, data_loader, optimizer, device):
    model.train()
    total_loss = 0
    for x_batch, y_batch in data_loader:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device).unsqueeze(1)  # (B,1)
        
        x_recon, mean, logvar = model(x_batch, y_batch)
        loss = beta_cvae_loss_fn(x_batch, x_recon, mean, logvar, beta=model.beta)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(data_loader)


# =========================
# 3. Transformer Detector
# =========================
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-np.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        self.pe = pe.unsqueeze(0)

    def forward(self, x):
        L = x.size(1)
        return x + self.pe[:, :L, :].to(x.device)

class TransformerDetector(nn.Module):
    def __init__(self, input_size, d_model=128, nhead=8, num_layers=2, dim_feedforward=256, dropout=0.1):
        super(TransformerDetector, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model,
                                                   nhead=nhead,
                                                   dim_feedforward=dim_feedforward, 
                                                   dropout=dropout,
                                                   batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.fc = nn.Sequential(
            nn.Linear(d_model, 128),
            nn.ReLU(),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        if x.dim() == 2:
            x = x.unsqueeze(1)
        x = self.embedding(x)
        x = self.positional_encoding(x)
        x = self.transformer_encoder(x)
        x = x.mean(dim=1)
        return self.fc(x).squeeze(1)

def train_detector(model, train_loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        y_pred = model(X_batch)  # (B,)
        loss = criterion(y_pred, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)

# %%
# =========================
# 4. MAIN DEMO
# =========================
if __name__ == "__main__":
    # Ví dụ đường dẫn
    dataset_path = r"D:\Study\Code\SwiftHydra\Classical\20_letter.npz"
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # 4.1: Load Data
    X_all, y_all = load_adbench_data(dataset_path)
    input_dim = X_all.shape[1]

    # Chia train/test
    X_train_np, X_test_np, y_train_np, y_test_np = train_test_split(
        X_all.numpy(), y_all.numpy(), test_size=0.2, random_state=42, stratify=y_all
    )
    X_train = torch.tensor(X_train_np, dtype=torch.float32)
    y_train = torch.tensor(y_train_np, dtype=torch.float32)
    X_test  = torch.tensor(X_test_np,  dtype=torch.float32)
    y_test  = torch.tensor(y_test_np,  dtype=torch.float32)

    # DataLoader cho Beta-CVAE
    train_dataset = TensorDataset(X_train, y_train)
    train_loader  = DataLoader(train_dataset, batch_size=64, shuffle=True)

    # 4.2: Khởi tạo Beta-CVAE
    # Tăng beta (vd=4.0) để nhấn mạnh KL -> latent space "trải rộng" hơn
    beta_cvae = BetaCVAE(input_dim=input_dim, hidden_dim=128, latent_dim=32, beta=1.0).to(device)
    optimizer_cvae = Adam(beta_cvae.parameters(), lr=1e-3)

# %%
# Train Beta-CVAE
num_epochs_cvae = 450
for epoch in range(num_epochs_cvae):
    loss_cvae = train_beta_cvae(beta_cvae, train_loader, optimizer_cvae, device)
    if (epoch + 1) % 2 == 0:
        print(f"[Beta-CVAE] Epoch {epoch+1}/{num_epochs_cvae}, loss={loss_cvae:.2f}")

# 4.3: Sinh dữ liệu - maximize diversity
"""
Thay vì z ~ Normal(0,1), ta thử z ~ Uniform([-2,2]) => 
tăng coverage, khuyến khích dữ liệu sinh ra đa dạng hơn
"""
beta_cvae.eval()
num_generate = 1120  # số lượng sample sinh ra
with torch.no_grad():
    # Tạo z uniform trong [-2,2]
    z_uniform = (torch.rand(num_generate, beta_cvae.latent_dim) * 4.0) - 2.0
    z_uniform = z_uniform.to(device)

    # Gán y=1 => oversample minority
    # hoặc y=0.7 => “lai”
    # Ở đây ta ví dụ oversample minority
    y_synthetic_c = torch.full((num_generate, 1), 0.9, device=device)

    # Decode
    X_synthetic = beta_cvae.decode(z_uniform, y_synthetic_c)
    X_synthetic = X_synthetic.cpu()

# Tạo label = 1 cho samples synthetic
y_synthetic_labels = torch.ones(num_generate)

# Ghép lại
X_train_final = torch.cat([X_train, X_synthetic], dim=0)
y_train_final = torch.cat([y_train, y_synthetic_labels], dim=0)
# Out:
# [Beta-CVAE] Epoch 2/450, loss=22211.34
# [Beta-CVAE] Epoch 4/450, loss=12135.84
# [Beta-CVAE] Epoch 6/450, loss=9685.31
# [Beta-CVAE] Epoch 8/450, loss=8034.91
# [Beta-CVAE] Epoch 10/450, loss=7133.80
# [Beta-CVAE] Epoch 12/450, loss=6725.19
# [Beta-CVAE] Epoch 14/450, loss=6263.37
# [Beta-CVAE] Epoch 16/450, loss=5897.69
# [Beta-CVAE] Epoch 18/450, loss=5580.42
# [Beta-CVAE] Epoch 20/450, loss=5290.38
# [Beta-CVAE] Epoch 22/450, loss=5075.09
# [Beta-CVAE] Epoch 24/450, loss=4893.22
# [Beta-CVAE] Epoch 26/450, loss=4728.98
# [Beta-CVAE] Epoch 28/450, loss=4552.06
# [Beta-CVAE] Epoch 30/450, loss=4446.83
# [Beta-CVAE] Epoch 32/450, loss=4343.34
# [Beta-CVAE] Epoch 34/450, loss=4251.07
# [Beta-CVAE] Epoch 36/450, loss=4183.89
# [Beta-CVAE] Epoch 378/450, loss=2193.19
# [Beta-CVAE] Epoch 380/450, loss=2202.38
# [Beta-CVAE] Epoch 382/450, loss=2195.15
# [Beta-CVAE] Epoch 384/450, loss=2176.81
# [Beta-CVAE] Epoch 386/450, loss=2162.02
# [Beta-CVAE] Epoch 388/450, loss=2178.85
# [Beta-CVAE] Epoch 390/450, loss=2163.93
# [Beta-CVAE] Epoch 392/450, loss=2165.07
# [Beta-CVAE] Epoch 394/450, loss=2175.15
# [Beta-CVAE] Epoch 396/450, loss=2181.30
# [Beta-CVAE] Epoch 398/450, loss=2169.00
# [Beta-CVAE] Epoch 400/450, loss=2162.84
# [Beta-CVAE] Epoch 402/450, loss=2146.63
# [Beta-CVAE] Epoch 404/450, loss=2158.20
# [Beta-CVAE] Epoch 406/450, loss=2164.53
# [Beta-CVAE] Epoch 408/450, loss=2151.70
# [Beta-CVAE] Epoch 410/450, loss=2157.89
# [Beta-CVAE] Epoch 412/450, loss=2165.77
# [Beta-CVAE] Epoch 414/450, loss=2154.42
# [Beta-CVAE] Epoch 416/450, loss=2160.40
# [Beta-CVAE] Epoch 418/450, loss=2154.19
# [Beta-CVAE] Epoch 420/450, loss=2167.03
# [Beta-CVAE] Epoch 422/450, loss=2159.31
# [Beta-CVAE] Epoch 424/450, loss=2146.84
# [Beta-CVAE] Epoch 426/450, loss=2155.45
# [Beta-CVAE] Epoch 428/450, loss=2158.00
# [Beta-CVAE] Epoch 430/450, loss=2146.17
# [Beta-CVAE] Epoch 432/450, loss=2142.82
# [Beta-CVAE] Epoch 434/450, loss=2142.12
# [Beta-CVAE] Epoch 436/450, loss=2146.47
# [Beta-CVAE] Epoch 438/450, loss=2146.66
# [Beta-CVAE] Epoch 440/450, loss=2144.00
# [Beta-CVAE] Epoch 442/450, loss=2126.08
# [Beta-CVAE] Epoch 444/450, loss=2144.01
# [Beta-CVAE] Epoch 446/450, loss=2130.31
# [Beta-CVAE] Epoch 448/450, loss=2143.08
# [Beta-CVAE] Epoch 450/450, loss=2143.10

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

plt.style.use('default')  # Đảm bảo sử dụng style mặc định

# Giả sử bạn đã có:
# X_train (Tensor) - dữ liệu gốc
# y_train (Tensor) - nhãn gốc (0 hoặc 1)
# X_synthetic (Tensor) - dữ liệu mới sinh
# y_synthetic_labels = torch.ones(...) hoặc bất kỳ (thường=1). 
# Nhưng để vẽ 3 màu, ta gán label=2 tạm thời khi plot.

# 1) Tạo mảng X_plot và y_plot
X_plot = torch.cat([X_train, X_synthetic], dim=0).numpy()

# Tạo y_plot: 
# - Phần đầu là y_train (0 hoặc 1) 
# - Phần sau (dữ liệu synthetic) sẽ là 2
N_original = len(X_train)
N_synthetic = len(X_synthetic)
y_plot = np.concatenate([
    y_train.numpy(), 
    np.full((N_synthetic,), 2)  # 2 = Synthetic
], axis=0)

# 2) Chuẩn hoá (nếu cần)
scaler = StandardScaler()
X_plot_scaled = scaler.fit_transform(X_plot)

# 3) Tính T-SNE
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
X_embedded = tsne.fit_transform(X_plot_scaled)  
# X_embedded.shape = (N_original + N_synthetic, 2)

# 4) Vẽ
plt.figure(figsize=(8, 6), facecolor='white')  # Đặt nền trắng

# class 0 (original) -> đỏ
idx0 = (y_plot == 0)
plt.scatter(X_embedded[idx0, 0], X_embedded[idx0, 1],
            c='red', alpha=0.6, label='Class 0')

# class 1 (original) -> xanh dương
idx1 = (y_plot == 1)
plt.scatter(X_embedded[idx1, 0], X_embedded[idx1, 1],
            c='blue', alpha=0.6, label='Class 1')

# class synthetic -> xanh lá
idx_syn = (y_plot == 2)
plt.scatter(X_embedded[idx_syn, 0], X_embedded[idx_syn, 1],
            c='green', alpha=0.6, label='Synthetic')

plt.title("T-SNE Visualization: Original (0,1) vs Synthetic (2)")
plt.legend()
plt.show()

# T-SNE với Test Set + Synthetic Data
# Dữ liệu gốc: X_test, y_test (0 hoặc 1)
# Dữ liệu sinh: X_synthetic, label giả định = 2

# 1) Gộp dữ liệu từ X_test (test) và X_synthetic (synthetic)
X_plot = torch.cat([X_test, X_synthetic], dim=0).numpy()

# Tạo mảng nhãn (test: 0, 1; synthetic: 2)
N_test = len(X_test)
N_synthetic = len(X_synthetic)
y_plot = np.concatenate([
    y_test.numpy(),             # Nhãn thực tế trên tập test (0, 1)
    np.full((N_synthetic,), 2)  # Gán nhãn 2 cho synthetic
], axis=0)

# 2) Chuẩn hoá dữ liệu (nếu cần)
scaler = StandardScaler()
X_plot_scaled = scaler.fit_transform(X_plot)

# 3) Tính T-SNE
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
X_embedded = tsne.fit_transform(X_plot_scaled)  
# X_embedded.shape = (N_test + N_synthetic, 2)

# 4) Vẽ
plt.figure(figsize=(8, 6), facecolor='white')  # Đặt nền trắng

# Test Class 0 -> đỏ
idx0_test = (y_plot == 0)
plt.scatter(X_embedded[idx0_test, 0], X_embedded[idx0_test, 1],
            c='red', alpha=0.6, label='Class 0 (Test)')

# Test Class 1 -> xanh dương
idx1_test = (y_plot == 1)
plt.scatter(X_embedded[idx1_test, 0], X_embedded[idx1_test, 1],
            c='blue', alpha=0.6, label='Class 1 (Test)')

# Synthetic Data -> xanh lá
idx_syn = (y_plot == 2)
plt.scatter(X_embedded[idx_syn, 0], X_embedded[idx_syn, 1],
            c='green', alpha=0.6, label='Synthetic')

plt.title("T-SNE Visualization: Test Data (Class 0, 1) vs Synthetic Data")
plt.legend()
plt.show()

# %%
# 4.4: Train mô hình TransformerDetector
train_dataset_final = TensorDataset(X_train_final, y_train_final)
test_dataset = TensorDataset(X_test, y_test)
train_loader_final = DataLoader(train_dataset_final, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64)
print("Sau khi oversampling bằng VAE:")
unique, counts = np.unique(y_train_final.numpy(), return_counts=True)
print("Phân phối lớp trong tập train:", dict(zip(unique, counts)))
model = TransformerDetector(input_size=input_dim).to(device)
optimizer_tf = Adam(model.parameters(), lr=1e-3)
criterion = nn.BCELoss()
# Out:
# Sau khi oversampling bằng VAE:
# Phân phối lớp trong tập train: {0.0: 1200, 1.0: 1200}

# %%
num_epochs_tf = 200
for epoch in range(num_epochs_tf):
    train_loss = train_detector(model, train_loader_final, optimizer_tf, criterion, device)
    print(f"[Transformer] Epoch {epoch+1}/{num_epochs_tf}, Loss={train_loss:.4f}")

    # Đánh giá
    print("Test set evaluation:")
    evaluate_with_classification_report_and_auc(model, test_loader, device, threshold=0.5)
    print("-" * 40)
# Out:
# [Transformer] Epoch 1/200, Loss=0.0048
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.98       300
#      Class 1       0.64      0.70      0.67        20
#
#     accuracy                           0.96       320
#    macro avg       0.81      0.84      0.82       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.8865
# ----------------------------------------
# [Transformer] Epoch 2/200, Loss=0.0050
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98       300
#      Class 1       0.68      0.75      0.71        20
#
#     accuracy                           0.96       320
#    macro avg       0.83      0.86      0.85       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9113
# ----------------------------------------
# [Transformer] Epoch 3/200, Loss=0.0039
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.64      0.80      0.71        20
#
#     accuracy                           0.96       320
#    macro avg       0.81      0.89      0.84       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9350
# ----------------------------------------
# [Transformer] Epoch 4/200, Loss=0.0838
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.95      0.97       300
#      Class 1       0.50      0.70      0.58        20
#
#     accuracy                           0.94       320
#    macro avg       0.74      0.83      0.77       320
# weighted avg       0.95      0.94      0.94       320
#
# AUC-ROC: 0.8732
# ----------------------------------------
# [Transformer] Epoch 5/200, Loss=0.0214
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98       300
#      Class 1       0.75      0.75      0.75        20
#
#     accuracy                           0.97       320
#    macro avg       0.87      0.87      0.87       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.8900
# ----------------------------------------
# [Transformer] Epoch 6/200, Loss=0.0157
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.96      0.97       300
#      Class 1       0.56      0.70      0.62        20
#
#     accuracy                           0.95       320
#    macro avg       0.77      0.83      0.80       320
# weighted avg       0.95      0.95      0.95       320
#
# AUC-ROC: 0.8785
# ----------------------------------------
# [Transformer] Epoch 7/200, Loss=0.0352
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.99      0.99       300
#      Class 1       0.79      0.75      0.77        20
#
#     accuracy                           0.97       320
#    macro avg       0.89      0.87      0.88       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.8633
# ----------------------------------------
# [Transformer] Epoch 8/200, Loss=0.0145
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.97       300
#      Class 1       0.60      0.75      0.67        20
#
#     accuracy                           0.95       320
#    macro avg       0.79      0.86      0.82       320
# weighted avg       0.96      0.95      0.96       320
#
# AUC-ROC: 0.9083
# ----------------------------------------
# [Transformer] Epoch 9/200, Loss=0.0194
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.96      0.97       300
#      Class 1       0.57      0.80      0.67        20
#
#     accuracy                           0.95       320
#    macro avg       0.78      0.88      0.82       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9425
# ----------------------------------------
# [Transformer] Epoch 10/200, Loss=0.0274
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.93      0.96       300
#      Class 1       0.41      0.70      0.52        20
#
#     accuracy                           0.92       320
#    macro avg       0.70      0.82      0.74       320
# weighted avg       0.94      0.92      0.93       320
#
# AUC-ROC: 0.8908
# ----------------------------------------
# [Transformer] Epoch 11/200, Loss=0.0336
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.98       300
#      Class 1       0.62      0.75      0.68        20
#
#     accuracy                           0.96       320
#    macro avg       0.80      0.86      0.83       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9255
# ----------------------------------------
# [Transformer] Epoch 12/200, Loss=0.0095
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      1.00      0.99       300
#      Class 1       0.94      0.75      0.83        20
#
#     accuracy                           0.98       320
#    macro avg       0.96      0.87      0.91       320
# weighted avg       0.98      0.98      0.98       320
#
# AUC-ROC: 0.9143
# ----------------------------------------
# [Transformer] Epoch 13/200, Loss=0.0028
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.98       300
#      Class 1       0.62      0.75      0.68        20
#
#     accuracy                           0.96       320
#    macro avg       0.80      0.86      0.83       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9125
# ----------------------------------------
# [Transformer] Epoch 14/200, Loss=0.0335
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.92      0.95       300
#      Class 1       0.38      0.75      0.50        20
#
#     accuracy                           0.91       320
#    macro avg       0.68      0.83      0.72       320
# weighted avg       0.94      0.91      0.92       320
#
# AUC-ROC: 0.8858
# ----------------------------------------
# [Transformer] Epoch 15/200, Loss=0.0276
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.94      0.96       300
#      Class 1       0.44      0.75      0.56        20
#
#     accuracy                           0.93       320
#    macro avg       0.71      0.84      0.76       320
# weighted avg       0.95      0.93      0.93       320
#
# AUC-ROC: 0.9007
# ----------------------------------------
# [Transformer] Epoch 16/200, Loss=0.0219
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.96      0.97       300
#      Class 1       0.52      0.70      0.60        20
#
#     accuracy                           0.94       320
#    macro avg       0.75      0.83      0.78       320
# weighted avg       0.95      0.94      0.94       320
#
# AUC-ROC: 0.9440
# ----------------------------------------
# [Transformer] Epoch 17/200, Loss=0.0272
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.96      0.97       300
#      Class 1       0.59      0.80      0.68        20
#
#     accuracy                           0.95       320
#    macro avg       0.79      0.88      0.83       320
# weighted avg       0.96      0.95      0.96       320
#
# AUC-ROC: 0.9687
# ----------------------------------------
# [Transformer] Epoch 18/200, Loss=0.0277
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.96      0.97       300
#      Class 1       0.56      0.75      0.64        20
#
#     accuracy                           0.95       320
#    macro avg       0.77      0.85      0.80       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9552
# ----------------------------------------
# [Transformer] Epoch 19/200, Loss=0.0109
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98       300
#      Class 1       0.70      0.70      0.70        20
#
#     accuracy                           0.96       320
#    macro avg       0.84      0.84      0.84       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9677
# ----------------------------------------
# [Transformer] Epoch 20/200, Loss=0.0143
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.95      0.96       300
#      Class 1       0.48      0.70      0.57        20
#
#     accuracy                           0.93       320
#    macro avg       0.73      0.82      0.77       320
# weighted avg       0.95      0.93      0.94       320
#
# AUC-ROC: 0.9297
# ----------------------------------------
# [Transformer] Epoch 21/200, Loss=0.0164
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.95      0.97       300
#      Class 1       0.50      0.70      0.58        20
#
#     accuracy                           0.94       320
#    macro avg       0.74      0.83      0.77       320
# weighted avg       0.95      0.94      0.94       320
#
# AUC-ROC: 0.9287
# ----------------------------------------
# [Transformer] Epoch 22/200, Loss=0.0318
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.97       300
#      Class 1       0.59      0.65      0.62        20
#
#     accuracy                           0.95       320
#    macro avg       0.78      0.81      0.80       320
# weighted avg       0.95      0.95      0.95       320
#
# AUC-ROC: 0.9217
# ----------------------------------------
# [Transformer] Epoch 23/200, Loss=0.0608
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98       300
#      Class 1       0.68      0.75      0.71        20
#
#     accuracy                           0.96       320
#    macro avg       0.83      0.86      0.85       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9592
# ----------------------------------------
# [Transformer] Epoch 24/200, Loss=0.0151
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.99      0.99       300
#      Class 1       0.79      0.75      0.77        20
#
#     accuracy                           0.97       320
#    macro avg       0.89      0.87      0.88       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9567
# ----------------------------------------
# [Transformer] Epoch 25/200, Loss=0.0248
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.95      0.97       300
#      Class 1       0.55      0.85      0.67        20
#
#     accuracy                           0.95       320
#    macro avg       0.77      0.90      0.82       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9377
# ----------------------------------------
# [Transformer] Epoch 26/200, Loss=0.0135
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98       300
#      Class 1       0.68      0.75      0.71        20
#
#     accuracy                           0.96       320
#    macro avg       0.83      0.86      0.85       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9728
# ----------------------------------------
# [Transformer] Epoch 27/200, Loss=0.0069
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.97       300
#      Class 1       0.57      0.65      0.60        20
#
#     accuracy                           0.95       320
#    macro avg       0.77      0.81      0.79       320
# weighted avg       0.95      0.95      0.95       320
#
# AUC-ROC: 0.8863
# ----------------------------------------
# [Transformer] Epoch 28/200, Loss=0.0032
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.98       300
#      Class 1       0.65      0.75      0.70        20
#
#     accuracy                           0.96       320
#    macro avg       0.82      0.86      0.84       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9477
# ----------------------------------------
# [Transformer] Epoch 29/200, Loss=0.0037
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.94      0.96       300
#      Class 1       0.47      0.75      0.58        20
#
#     accuracy                           0.93       320
#    macro avg       0.73      0.85      0.77       320
# weighted avg       0.95      0.93      0.94       320
#
# AUC-ROC: 0.9200
# ----------------------------------------
# [Transformer] Epoch 30/200, Loss=0.0247
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.99      0.99       300
#      Class 1       0.79      0.75      0.77        20
#
#     accuracy                           0.97       320
#    macro avg       0.89      0.87      0.88       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9523
# ----------------------------------------
# [Transformer] Epoch 31/200, Loss=0.0356
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.95      0.97       300
#      Class 1       0.50      0.80      0.62        20
#
#     accuracy                           0.94       320
#    macro avg       0.74      0.87      0.79       320
# weighted avg       0.96      0.94      0.94       320
#
# AUC-ROC: 0.9392
# ----------------------------------------
# [Transformer] Epoch 32/200, Loss=0.0200
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.94      0.96       300
#      Class 1       0.47      0.80      0.59        20
#
#     accuracy                           0.93       320
#    macro avg       0.73      0.87      0.78       320
# weighted avg       0.95      0.93      0.94       320
#
# AUC-ROC: 0.8923
# ----------------------------------------
# [Transformer] Epoch 33/200, Loss=0.0155
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.95      0.97       300
#      Class 1       0.52      0.75      0.61        20
#
#     accuracy                           0.94       320
#    macro avg       0.75      0.85      0.79       320
# weighted avg       0.95      0.94      0.95       320
#
# AUC-ROC: 0.8743
# ----------------------------------------
# [Transformer] Epoch 34/200, Loss=0.0104
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.95      0.96       300
#      Class 1       0.45      0.65      0.53        20
#
#     accuracy                           0.93       320
#    macro avg       0.71      0.80      0.75       320
# weighted avg       0.94      0.93      0.93       320
#
# AUC-ROC: 0.8690
# ----------------------------------------
# [Transformer] Epoch 35/200, Loss=0.0302
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.98       300
#      Class 1       0.64      0.70      0.67        20
#
#     accuracy                           0.96       320
#    macro avg       0.81      0.84      0.82       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9525
# ----------------------------------------
# [Transformer] Epoch 36/200, Loss=0.0286
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.96      0.97       300
#      Class 1       0.56      0.75      0.64        20
#
#     accuracy                           0.95       320
#    macro avg       0.77      0.85      0.80       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9372
# ----------------------------------------
# [Transformer] Epoch 37/200, Loss=0.0212
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.94      0.96       300
#      Class 1       0.48      0.80      0.60        20
#
#     accuracy                           0.93       320
#    macro avg       0.74      0.87      0.78       320
# weighted avg       0.95      0.93      0.94       320
#
# AUC-ROC: 0.9503
# ----------------------------------------
# [Transformer] Epoch 38/200, Loss=0.0214
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.96      0.97       300
#      Class 1       0.55      0.80      0.65        20
#
#     accuracy                           0.95       320
#    macro avg       0.77      0.88      0.81       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.8843
# ----------------------------------------
# [Transformer] Epoch 39/200, Loss=0.0107
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.92      0.95       300
#      Class 1       0.39      0.75      0.52        20
#
#     accuracy                           0.91       320
#    macro avg       0.69      0.84      0.73       320
# weighted avg       0.95      0.91      0.92       320
#
# AUC-ROC: 0.9247
# ----------------------------------------
# [Transformer] Epoch 40/200, Loss=0.0405
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.96      0.97       300
#      Class 1       0.57      0.85      0.68        20
#
#     accuracy                           0.95       320
#    macro avg       0.78      0.90      0.83       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9528
# ----------------------------------------
# [Transformer] Epoch 41/200, Loss=0.0281
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.95      0.97       300
#      Class 1       0.52      0.75      0.61        20
#
#     accuracy                           0.94       320
#    macro avg       0.75      0.85      0.79       320
# weighted avg       0.95      0.94      0.95       320
#
# AUC-ROC: 0.9757
# ----------------------------------------
# [Transformer] Epoch 42/200, Loss=0.0155
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.96      0.97       300
#      Class 1       0.54      0.75      0.62        20
#
#     accuracy                           0.94       320
#    macro avg       0.76      0.85      0.80       320
# weighted avg       0.95      0.94      0.95       320
#
# AUC-ROC: 0.9177
# ----------------------------------------
# [Transformer] Epoch 43/200, Loss=0.0354
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.98       300
#      Class 1       0.64      0.70      0.67        20
#
#     accuracy                           0.96       320
#    macro avg       0.81      0.84      0.82       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9342
# ----------------------------------------
# [Transformer] Epoch 44/200, Loss=0.0051
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.97       300
#      Class 1       0.58      0.70      0.64        20
#
#     accuracy                           0.95       320
#    macro avg       0.78      0.83      0.80       320
# weighted avg       0.95      0.95      0.95       320
#
# AUC-ROC: 0.9215
# ----------------------------------------
# [Transformer] Epoch 45/200, Loss=0.0011
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.97       300
#      Class 1       0.60      0.75      0.67        20
#
#     accuracy                           0.95       320
#    macro avg       0.79      0.86      0.82       320
# weighted avg       0.96      0.95      0.96       320
#
# AUC-ROC: 0.9137
# ----------------------------------------
# [Transformer] Epoch 46/200, Loss=0.0054
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.98       300
#      Class 1       0.64      0.70      0.67        20
#
#     accuracy                           0.96       320
#    macro avg       0.81      0.84      0.82       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.8743
# ----------------------------------------
# [Transformer] Epoch 47/200, Loss=0.0366
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.95      0.97       300
#      Class 1       0.52      0.80      0.63        20
#
#     accuracy                           0.94       320
#    macro avg       0.75      0.88      0.80       320
# weighted avg       0.96      0.94      0.95       320
#
# AUC-ROC: 0.8943
# ----------------------------------------
# [Transformer] Epoch 48/200, Loss=0.0218
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.93      0.96       300
#      Class 1       0.49      0.95      0.64        20
#
#     accuracy                           0.93       320
#    macro avg       0.74      0.94      0.80       320
# weighted avg       0.96      0.93      0.94       320
#
# AUC-ROC: 0.9582
# ----------------------------------------
# [Transformer] Epoch 49/200, Loss=0.0296
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.96      0.97       300
#      Class 1       0.54      0.75      0.62        20
#
#     accuracy                           0.94       320
#    macro avg       0.76      0.85      0.80       320
# weighted avg       0.95      0.94      0.95       320
#
# AUC-ROC: 0.8667
# ----------------------------------------
# [Transformer] Epoch 50/200, Loss=0.0134
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.99      0.98       300
#      Class 1       0.78      0.70      0.74        20
#
#     accuracy                           0.97       320
#    macro avg       0.88      0.84      0.86       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.8897
# ----------------------------------------
# [Transformer] Epoch 51/200, Loss=0.0296
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98       300
#      Class 1       0.68      0.75      0.71        20
#
#     accuracy                           0.96       320
#    macro avg       0.83      0.86      0.85       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9137
# ----------------------------------------
# [Transformer] Epoch 52/200, Loss=0.0325
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.95      0.97       300
#      Class 1       0.50      0.75      0.60        20
#
#     accuracy                           0.94       320
#    macro avg       0.74      0.85      0.78       320
# weighted avg       0.95      0.94      0.94       320
#
# AUC-ROC: 0.9430
# ----------------------------------------
# [Transformer] Epoch 53/200, Loss=0.0304
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.96      0.97       300
#      Class 1       0.56      0.70      0.62        20
#
#     accuracy                           0.95       320
#    macro avg       0.77      0.83      0.80       320
# weighted avg       0.95      0.95      0.95       320
#
# AUC-ROC: 0.8683
# ----------------------------------------
# [Transformer] Epoch 54/200, Loss=0.0255
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.97       300
#      Class 1       0.61      0.70      0.65        20
#
#     accuracy                           0.95       320
#    macro avg       0.79      0.83      0.81       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9043
# ----------------------------------------
# [Transformer] Epoch 55/200, Loss=0.0216
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.98       300
#      Class 1       0.70      0.80      0.74        20
#
#     accuracy                           0.97       320
#    macro avg       0.84      0.89      0.86       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9117
# ----------------------------------------
# [Transformer] Epoch 56/200, Loss=0.0039
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.99      0.99       300
#      Class 1       0.80      0.80      0.80        20
#
#     accuracy                           0.97       320
#    macro avg       0.89      0.89      0.89       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9142
# ----------------------------------------
# [Transformer] Epoch 57/200, Loss=0.0019
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98       300
#      Class 1       0.71      0.75      0.73        20
#
#     accuracy                           0.97       320
#    macro avg       0.85      0.86      0.86       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9137
# ----------------------------------------
# [Transformer] Epoch 58/200, Loss=0.0253
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.99      0.99       300
#      Class 1       0.84      0.80      0.82        20
#
#     accuracy                           0.98       320
#    macro avg       0.91      0.90      0.90       320
# weighted avg       0.98      0.98      0.98       320
#
# AUC-ROC: 0.9250
# ----------------------------------------
# [Transformer] Epoch 59/200, Loss=0.0088
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.96      0.97       300
#      Class 1       0.56      0.75      0.64        20
#
#     accuracy                           0.95       320
#    macro avg       0.77      0.85      0.80       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9057
# ----------------------------------------
# [Transformer] Epoch 60/200, Loss=0.0274
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.95      0.97       300
#      Class 1       0.53      0.80      0.64        20
#
#     accuracy                           0.94       320
#    macro avg       0.76      0.88      0.80       320
# weighted avg       0.96      0.94      0.95       320
#
# AUC-ROC: 0.9215
# ----------------------------------------
# [Transformer] Epoch 61/200, Loss=0.0131
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.98       300
#      Class 1       0.70      0.80      0.74        20
#
#     accuracy                           0.97       320
#    macro avg       0.84      0.89      0.86       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9218
# ----------------------------------------
# [Transformer] Epoch 62/200, Loss=0.0064
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98       300
#      Class 1       0.68      0.75      0.71        20
#
#     accuracy                           0.96       320
#    macro avg       0.83      0.86      0.85       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9508
# ----------------------------------------
# [Transformer] Epoch 63/200, Loss=0.0022
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.96      0.97       300
#      Class 1       0.55      0.80      0.65        20
#
#     accuracy                           0.95       320
#    macro avg       0.77      0.88      0.81       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9185
# ----------------------------------------
# [Transformer] Epoch 64/200, Loss=0.0191
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.94      0.96       300
#      Class 1       0.47      0.80      0.59        20
#
#     accuracy                           0.93       320
#    macro avg       0.73      0.87      0.78       320
# weighted avg       0.95      0.93      0.94       320
#
# AUC-ROC: 0.9180
# ----------------------------------------
# [Transformer] Epoch 65/200, Loss=0.0175
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98       300
#      Class 1       0.68      0.65      0.67        20
#
#     accuracy                           0.96       320
#    macro avg       0.83      0.81      0.82       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9000
# ----------------------------------------
# [Transformer] Epoch 66/200, Loss=0.0229
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98       300
#      Class 1       0.68      0.75      0.71        20
#
#     accuracy                           0.96       320
#    macro avg       0.83      0.86      0.85       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9195
# ----------------------------------------
# [Transformer] Epoch 67/200, Loss=0.0142
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.96      0.97       300
#      Class 1       0.54      0.75      0.62        20
#
#     accuracy                           0.94       320
#    macro avg       0.76      0.85      0.80       320
# weighted avg       0.95      0.94      0.95       320
#
# AUC-ROC: 0.9115
# ----------------------------------------
# [Transformer] Epoch 68/200, Loss=0.0223
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.99      0.98       300
#      Class 1       0.78      0.70      0.74        20
#
#     accuracy                           0.97       320
#    macro avg       0.88      0.84      0.86       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9200
# ----------------------------------------
# [Transformer] Epoch 69/200, Loss=0.0188
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.99      0.99       300
#      Class 1       0.85      0.85      0.85        20
#
#     accuracy                           0.98       320
#    macro avg       0.92      0.92      0.92       320
# weighted avg       0.98      0.98      0.98       320
#
# AUC-ROC: 0.9773
# ----------------------------------------
# [Transformer] Epoch 70/200, Loss=0.0109
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.99      0.99       300
#      Class 1       0.80      0.80      0.80        20
#
#     accuracy                           0.97       320
#    macro avg       0.89      0.89      0.89       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9677
# ----------------------------------------
# [Transformer] Epoch 71/200, Loss=0.0068
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.98       300
#      Class 1       0.74      0.85      0.79        20
#
#     accuracy                           0.97       320
#    macro avg       0.86      0.92      0.89       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9638
# ----------------------------------------
# [Transformer] Epoch 72/200, Loss=0.0336
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.96      0.97       300
#      Class 1       0.58      0.75      0.65        20
#
#     accuracy                           0.95       320
#    macro avg       0.78      0.86      0.81       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9762
# ----------------------------------------
# [Transformer] Epoch 73/200, Loss=0.0200
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      1.00      0.99       300
#      Class 1       0.94      0.85      0.89        20
#
#     accuracy                           0.99       320
#    macro avg       0.97      0.92      0.94       320
# weighted avg       0.99      0.99      0.99       320
#
# AUC-ROC: 0.9168
# ----------------------------------------
# [Transformer] Epoch 74/200, Loss=0.0240
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.96      0.97       300
#      Class 1       0.55      0.80      0.65        20
#
#     accuracy                           0.95       320
#    macro avg       0.77      0.88      0.81       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9797
# ----------------------------------------
# [Transformer] Epoch 75/200, Loss=0.0104
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.98       300
#      Class 1       0.76      0.80      0.78        20
#
#     accuracy                           0.97       320
#    macro avg       0.87      0.89      0.88       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9467
# ----------------------------------------
# [Transformer] Epoch 76/200, Loss=0.0065
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.92      0.95       300
#      Class 1       0.41      0.80      0.54        20
#
#     accuracy                           0.92       320
#    macro avg       0.70      0.86      0.75       320
# weighted avg       0.95      0.92      0.93       320
#
# AUC-ROC: 0.9425
# ----------------------------------------
# [Transformer] Epoch 77/200, Loss=0.0327
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.67      0.80      0.73        20
#
#     accuracy                           0.96       320
#    macro avg       0.83      0.89      0.85       320
# weighted avg       0.97      0.96      0.96       320
#
# AUC-ROC: 0.9247
# ----------------------------------------
# [Transformer] Epoch 78/200, Loss=0.0331
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.98       300
#      Class 1       0.73      0.80      0.76        20
#
#     accuracy                           0.97       320
#    macro avg       0.86      0.89      0.87       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9190
# ----------------------------------------
# [Transformer] Epoch 79/200, Loss=0.0184
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.96      0.97       300
#      Class 1       0.59      0.85      0.69        20
#
#     accuracy                           0.95       320
#    macro avg       0.79      0.91      0.83       320
# weighted avg       0.96      0.95      0.96       320
#
# AUC-ROC: 0.9327
# ----------------------------------------
# [Transformer] Epoch 80/200, Loss=0.0106
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.96      0.97       300
#      Class 1       0.55      0.80      0.65        20
#
#     accuracy                           0.95       320
#    macro avg       0.77      0.88      0.81       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9640
# ----------------------------------------
# [Transformer] Epoch 81/200, Loss=0.0068
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.67      0.80      0.73        20
#
#     accuracy                           0.96       320
#    macro avg       0.83      0.89      0.85       320
# weighted avg       0.97      0.96      0.96       320
#
# AUC-ROC: 0.9705
# ----------------------------------------
# [Transformer] Epoch 82/200, Loss=0.0116
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.67      0.80      0.73        20
#
#     accuracy                           0.96       320
#    macro avg       0.83      0.89      0.85       320
# weighted avg       0.97      0.96      0.96       320
#
# AUC-ROC: 0.9700
# ----------------------------------------
# [Transformer] Epoch 83/200, Loss=0.0155
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.99       300
#      Class 1       0.75      0.90      0.82        20
#
#     accuracy                           0.97       320
#    macro avg       0.87      0.94      0.90       320
# weighted avg       0.98      0.97      0.98       320
#
# AUC-ROC: 0.9638
# ----------------------------------------
# [Transformer] Epoch 84/200, Loss=0.0231
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.97       300
#      Class 1       0.60      0.75      0.67        20
#
#     accuracy                           0.95       320
#    macro avg       0.79      0.86      0.82       320
# weighted avg       0.96      0.95      0.96       320
#
# AUC-ROC: 0.9617
# ----------------------------------------
# [Transformer] Epoch 85/200, Loss=0.0185
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.99      0.99       300
#      Class 1       0.83      0.75      0.79        20
#
#     accuracy                           0.97       320
#    macro avg       0.91      0.87      0.89       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9392
# ----------------------------------------
# [Transformer] Epoch 86/200, Loss=0.0137
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.99      0.99       300
#      Class 1       0.83      0.75      0.79        20
#
#     accuracy                           0.97       320
#    macro avg       0.91      0.87      0.89       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9390
# ----------------------------------------
# [Transformer] Epoch 87/200, Loss=0.0130
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.97       300
#      Class 1       0.61      0.70      0.65        20
#
#     accuracy                           0.95       320
#    macro avg       0.79      0.83      0.81       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9323
# ----------------------------------------
# [Transformer] Epoch 88/200, Loss=0.0336
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.64      0.80      0.71        20
#
#     accuracy                           0.96       320
#    macro avg       0.81      0.89      0.84       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9455
# ----------------------------------------
# [Transformer] Epoch 89/200, Loss=0.0153
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.98       300
#      Class 1       0.74      0.85      0.79        20
#
#     accuracy                           0.97       320
#    macro avg       0.86      0.92      0.89       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9478
# ----------------------------------------
# [Transformer] Epoch 90/200, Loss=0.0174
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.96      0.97       300
#      Class 1       0.59      0.85      0.69        20
#
#     accuracy                           0.95       320
#    macro avg       0.79      0.91      0.83       320
# weighted avg       0.96      0.95      0.96       320
#
# AUC-ROC: 0.9432
# ----------------------------------------
# [Transformer] Epoch 91/200, Loss=0.0168
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.98       300
#      Class 1       0.71      0.85      0.77        20
#
#     accuracy                           0.97       320
#    macro avg       0.85      0.91      0.88       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9390
# ----------------------------------------
# [Transformer] Epoch 92/200, Loss=0.0162
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.68      0.85      0.76        20
#
#     accuracy                           0.97       320
#    macro avg       0.83      0.91      0.87       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9828
# ----------------------------------------
# [Transformer] Epoch 93/200, Loss=0.0099
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.94      0.96       300
#      Class 1       0.45      0.75      0.57        20
#
#     accuracy                           0.93       320
#    macro avg       0.72      0.84      0.76       320
# weighted avg       0.95      0.93      0.94       320
#
# AUC-ROC: 0.9298
# ----------------------------------------
# [Transformer] Epoch 94/200, Loss=0.0232
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98       300
#      Class 1       0.72      0.65      0.68        20
#
#     accuracy                           0.96       320
#    macro avg       0.85      0.82      0.83       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9018
# ----------------------------------------
# [Transformer] Epoch 95/200, Loss=0.0173
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.97      0.97       300
#      Class 1       0.60      0.75      0.67        20
#
#     accuracy                           0.95       320
#    macro avg       0.79      0.86      0.82       320
# weighted avg       0.96      0.95      0.96       320
#
# AUC-ROC: 0.8873
# ----------------------------------------
# [Transformer] Epoch 96/200, Loss=0.0315
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.68      0.85      0.76        20
#
#     accuracy                           0.97       320
#    macro avg       0.83      0.91      0.87       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9890
# ----------------------------------------
# [Transformer] Epoch 97/200, Loss=0.0294
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.99       300
#      Class 1       0.75      0.90      0.82        20
#
#     accuracy                           0.97       320
#    macro avg       0.87      0.94      0.90       320
# weighted avg       0.98      0.97      0.98       320
#
# AUC-ROC: 0.9562
# ----------------------------------------
# [Transformer] Epoch 98/200, Loss=0.0762
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.64      0.90      0.75        20
#
#     accuracy                           0.96       320
#    macro avg       0.82      0.93      0.86       320
# weighted avg       0.97      0.96      0.97       320
#
# AUC-ROC: 0.9502
# ----------------------------------------
# [Transformer] Epoch 99/200, Loss=0.0254
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      1.00      0.99       300
#      Class 1       0.94      0.85      0.89        20
#
#     accuracy                           0.99       320
#    macro avg       0.97      0.92      0.94       320
# weighted avg       0.99      0.99      0.99       320
#
# AUC-ROC: 0.9683
# ----------------------------------------
# [Transformer] Epoch 100/200, Loss=0.0121
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.98       300
#      Class 1       0.73      0.80      0.76        20
#
#     accuracy                           0.97       320
#    macro avg       0.86      0.89      0.87       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9400
# ----------------------------------------
# [Transformer] Epoch 101/200, Loss=0.0327
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.98       300
#      Class 1       0.74      0.85      0.79        20
#
#     accuracy                           0.97       320
#    macro avg       0.86      0.92      0.89       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9657
# ----------------------------------------
# [Transformer] Epoch 102/200, Loss=0.0287
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.67      0.80      0.73        20
#
#     accuracy                           0.96       320
#    macro avg       0.83      0.89      0.85       320
# weighted avg       0.97      0.96      0.96       320
#
# AUC-ROC: 0.9400
# ----------------------------------------
# [Transformer] Epoch 103/200, Loss=0.0039
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.96      0.98       300
#      Class 1       0.61      0.85      0.71        20
#
#     accuracy                           0.96       320
#    macro avg       0.80      0.91      0.84       320
# weighted avg       0.97      0.96      0.96       320
#
# AUC-ROC: 0.9377
# ----------------------------------------
# [Transformer] Epoch 104/200, Loss=0.0070
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.95      0.97       300
#      Class 1       0.55      0.85      0.67        20
#
#     accuracy                           0.95       320
#    macro avg       0.77      0.90      0.82       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9485
# ----------------------------------------
# [Transformer] Epoch 105/200, Loss=0.0072
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.99      0.99       300
#      Class 1       0.80      0.80      0.80        20
#
#     accuracy                           0.97       320
#    macro avg       0.89      0.89      0.89       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9713
# ----------------------------------------
# [Transformer] Epoch 106/200, Loss=0.0118
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.96      0.97       300
#      Class 1       0.59      0.80      0.68        20
#
#     accuracy                           0.95       320
#    macro avg       0.79      0.88      0.83       320
# weighted avg       0.96      0.95      0.96       320
#
# AUC-ROC: 0.9450
# ----------------------------------------
# [Transformer] Epoch 107/200, Loss=0.0296
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.98       300
#      Class 1       0.70      0.80      0.74        20
#
#     accuracy                           0.97       320
#    macro avg       0.84      0.89      0.86       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9418
# ----------------------------------------
# [Transformer] Epoch 108/200, Loss=0.0269
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.67      0.80      0.73        20
#
#     accuracy                           0.96       320
#    macro avg       0.83      0.89      0.85       320
# ...
# weighted avg       0.97      0.96      0.96       320
#
# AUC-ROC: 0.9633
# ----------------------------------------
# [Transformer] Epoch 160/200, Loss=0.0146
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.64      0.80      0.71        20
#
#     accuracy                           0.96       320
#    macro avg       0.81      0.89      0.84       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9532
# ----------------------------------------
# [Transformer] Epoch 161/200, Loss=0.0304
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.96      0.98       300
#      Class 1       0.61      0.85      0.71        20
#
#     accuracy                           0.96       320
#    macro avg       0.80      0.91      0.84       320
# weighted avg       0.97      0.96      0.96       320
#
# AUC-ROC: 0.9507
# ----------------------------------------
# [Transformer] Epoch 162/200, Loss=0.0072
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.98       300
#      Class 1       0.73      0.80      0.76        20
#
#     accuracy                           0.97       320
#    macro avg       0.86      0.89      0.87       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9660
# ----------------------------------------
# [Transformer] Epoch 163/200, Loss=0.0025
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.99      0.99       300
#      Class 1       0.84      0.80      0.82        20
#
#     accuracy                           0.98       320
#    macro avg       0.91      0.90      0.90       320
# weighted avg       0.98      0.98      0.98       320
#
# AUC-ROC: 0.9512
# ----------------------------------------
# [Transformer] Epoch 164/200, Loss=0.0103
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.96      0.97       300
#      Class 1       0.52      0.70      0.60        20
#
#     accuracy                           0.94       320
#    macro avg       0.75      0.83      0.78       320
# weighted avg       0.95      0.94      0.94       320
#
# AUC-ROC: 0.9348
# ----------------------------------------
# [Transformer] Epoch 165/200, Loss=0.0213
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.92      0.96       300
#      Class 1       0.45      0.95      0.61        20
#
#     accuracy                           0.93       320
#    macro avg       0.72      0.94      0.79       320
# weighted avg       0.96      0.93      0.94       320
#
# AUC-ROC: 0.9582
# ----------------------------------------
# [Transformer] Epoch 166/200, Loss=0.0229
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.99      0.99       300
#      Class 1       0.83      0.75      0.79        20
#
#     accuracy                           0.97       320
#    macro avg       0.91      0.87      0.89       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9862
# ----------------------------------------
# [Transformer] Epoch 167/200, Loss=0.0052
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.98       300
#      Class 1       0.70      0.80      0.74        20
#
#     accuracy                           0.97       320
#    macro avg       0.84      0.89      0.86       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9748
# ----------------------------------------
# [Transformer] Epoch 168/200, Loss=0.0415
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.62      0.80      0.70        20
#
#     accuracy                           0.96       320
#    macro avg       0.80      0.88      0.84       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9578
# ----------------------------------------
# [Transformer] Epoch 169/200, Loss=0.0142
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.99      0.99       300
#      Class 1       0.88      0.75      0.81        20
#
#     accuracy                           0.98       320
#    macro avg       0.93      0.87      0.90       320
# weighted avg       0.98      0.98      0.98       320
#
# AUC-ROC: 0.9372
# ----------------------------------------
# [Transformer] Epoch 170/200, Loss=0.0077
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.67      0.80      0.73        20
#
#     accuracy                           0.96       320
#    macro avg       0.83      0.89      0.85       320
# weighted avg       0.97      0.96      0.96       320
#
# AUC-ROC: 0.9303
# ----------------------------------------
# [Transformer] Epoch 171/200, Loss=0.0016
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.99      0.99       300
#      Class 1       0.89      0.80      0.84        20
#
#     accuracy                           0.98       320
#    macro avg       0.94      0.90      0.92       320
# weighted avg       0.98      0.98      0.98       320
#
# AUC-ROC: 0.9545
# ----------------------------------------
# [Transformer] Epoch 172/200, Loss=0.0011
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      1.00      0.99       300
#      Class 1       0.94      0.80      0.86        20
#
#     accuracy                           0.98       320
#    macro avg       0.96      0.90      0.93       320
# weighted avg       0.98      0.98      0.98       320
#
# AUC-ROC: 0.9592
# ----------------------------------------
# [Transformer] Epoch 173/200, Loss=0.0254
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.62      0.80      0.70        20
#
#     accuracy                           0.96       320
#    macro avg       0.80      0.88      0.84       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9432
# ----------------------------------------
# [Transformer] Epoch 174/200, Loss=0.0311
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.99      0.99       300
#      Class 1       0.81      0.85      0.83        20
#
#     accuracy                           0.98       320
#    macro avg       0.90      0.92      0.91       320
# weighted avg       0.98      0.98      0.98       320
#
# AUC-ROC: 0.9758
# ----------------------------------------
# [Transformer] Epoch 175/200, Loss=0.0077
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.99      0.99       300
#      Class 1       0.79      0.75      0.77        20
#
#     accuracy                           0.97       320
#    macro avg       0.89      0.87      0.88       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9425
# ----------------------------------------
# [Transformer] Epoch 176/200, Loss=0.0163
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.63      0.85      0.72        20
#
#     accuracy                           0.96       320
#    macro avg       0.81      0.91      0.85       320
# weighted avg       0.97      0.96      0.96       320
#
# AUC-ROC: 0.9387
# ----------------------------------------
# [Transformer] Epoch 177/200, Loss=0.0332
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.98      0.98       300
#      Class 1       0.73      0.80      0.76        20
#
#     accuracy                           0.97       320
#    macro avg       0.86      0.89      0.87       320
# weighted avg       0.97      0.97      0.97       320
#
# AUC-ROC: 0.9533
# ----------------------------------------
# [Transformer] Epoch 178/200, Loss=0.0069
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.95      0.97       300
#      Class 1       0.55      0.85      0.67        20
#
#     accuracy                           0.95       320
#    macro avg       0.77      0.90      0.82       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9742
# ----------------------------------------
# [Transformer] Epoch 179/200, Loss=0.0066
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      1.00      0.99       300
#      Class 1       1.00      0.80      0.89        20
#
#     accuracy                           0.99       320
#    macro avg       0.99      0.90      0.94       320
# weighted avg       0.99      0.99      0.99       320
#
# AUC-ROC: 0.9618
# ----------------------------------------
# [Transformer] Epoch 180/200, Loss=0.0063
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.63      0.85      0.72        20
#
#     accuracy                           0.96       320
#    macro avg       0.81      0.91      0.85       320
# weighted avg       0.97      0.96      0.96       320
#
# AUC-ROC: 0.9533
# ----------------------------------------
# [Transformer] Epoch 181/200, Loss=0.0044
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.64      0.80      0.71        20
#
#     accuracy                           0.96       320
#    macro avg       0.81      0.89      0.84       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9630
# ----------------------------------------
# [Transformer] Epoch 182/200, Loss=0.0248
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.64      0.90      0.75        20
#
#     accuracy                           0.96       320
#    macro avg       0.82      0.93      0.86       320
# weighted avg       0.97      0.96      0.97       320
#
# AUC-ROC: 0.9805
# ----------------------------------------
# [Transformer] Epoch 183/200, Loss=0.0350
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.96      0.97       300
#      Class 1       0.58      0.75      0.65        20
#
#     accuracy                           0.95       320
#    macro avg       0.78      0.86      0.81       320
# weighted avg       0.96      0.95      0.95       320
#
# AUC-ROC: 0.9327
# ----------------------------------------
# [Transformer] Epoch 184/200, Loss=0.0314
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.99      0.97      0.98       300
#      Class 1       0.63      0.85      0.72        20
#
#     accuracy                           0.96       320
#    macro avg       0.81      0.91      0.85       320
# weighted avg       0.97      0.96      0.96       320
#
# AUC-ROC: 0.9593
# ----------------------------------------
# [Transformer] Epoch 185/200, Loss=0.0114
# Test set evaluation:
#               precision    recall  f1-score   support
#
#      Class 0       0.98      0.98      0.98       300
#      Class 1       0.70      0.70      0.70        20
#
#     accuracy                           0.96       320
#    macro avg       0.84      0.84      0.84       320
# weighted avg       0.96      0.96      0.96       320
#
# AUC-ROC: 0.9378
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 3
#       1 num_epochs_tf = 200
#       2 for epoch in range(num_epochs_tf):
# ----> 3     train_loss = train_detector(model, train_loader_final, optimizer_tf, criterion, device)
#       4     print(f"[Transformer] Epoch {epoch+1}/{num_epochs_tf}, Loss={train_loss:.4f}")
#       6     # Đánh giá
#
# Cell In[1], line 171, in train_detector(model, train_loader, optimizer, criterion, device)
#     169 model.train()
#     170 total_loss = 0
# --> 171 for X_batch, y_batch in train_loader:
#     172     X_batch, y_batch = X_batch.to(device), y_batch.to(device)
#     173     y_pred = model(X_batch)  # (B,)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\collate.py:398, in default_collate(batch)
#     337 def default_collate(batch):
#     338     r"""
#     339     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     340
#    (...)
#     396         >>> default_collate(batch)  # Handle `CustomType` automatically
#     397     """
# --> 398     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\collate.py:211, in collate(batch, collate_fn_map)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
# --> 211     return [
#     212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\collate.py:212, in <listcomp>(.0)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
#     211     return [
# --> 212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\collate.py:155, in collate(batch, collate_fn_map)
#     153 if collate_fn_map is not None:
#     154     if elem_type in collate_fn_map:
# --> 155         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     157     for collate_type in collate_fn_map:
#     158         if isinstance(elem, collate_type):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\_utils\collate.py:272, in collate_tensor_fn(batch, collate_fn_map)
#     270     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     271     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 272 return torch.stack(batch, 0, out=out)
#
# KeyboardInterrupt:
