# %%
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, roc_auc_score
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
import numpy as np
from sklearn.model_selection import train_test_split

# Positional Encoding
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-np.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        self.pe = pe.unsqueeze(0)

    def forward(self, x):
        L = x.size(1)
        return x + self.pe[:, :L, :].to(x.device)

# Transformer Detector Model
class TransformerDetector(nn.Module):
    def __init__(self, input_size, d_model=128, nhead=8, num_layers=2, dim_feedforward=256, dropout=0.1):
        super(TransformerDetector, self).__init__()
        self.embedding = nn.Linear(input_size, d_model)
        self.positional_encoding = PositionalEncoding(d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dim_feedforward=dim_feedforward, dropout=dropout, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.fc = nn.Sequential(
            nn.Linear(d_model, 128),
            nn.ReLU(),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        if x.dim() == 2:  # Nếu không có chiều sequence
            x = x.unsqueeze(1)  # [B, d_input] -> [B, 1, d_input]
        x = self.embedding(x)  # [B, L, d_model]
        x = self.positional_encoding(x)  # Add positional encoding
        x = self.transformer_encoder(x)  # [B, L, d_model]
        x = x.mean(dim=1)  # Average pooling over sequence length
        return self.fc(x)

# %%
# Load Data and Preprocess
def load_adbench_data(dataset_path):
    data = np.load(dataset_path)
    X = data['X']
    y = data['y']
    return torch.tensor(X, dtype=torch.float32), torch.tensor(y, dtype=torch.float32)

def evaluate_with_classification_report_and_auc(model, test_loader, device, threshold=0.5):
    """
    Đánh giá mô hình với classification_report và in AUC-ROC.
    """
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_pred = model(X_batch).squeeze()
            all_preds.append(y_pred.cpu())
            all_labels.append(y_batch.cpu())

    # Gộp tất cả batch lại
    preds = torch.cat(all_preds).numpy()
    labels = torch.cat(all_labels).numpy()

    # Chuyển dự đoán thành nhị phân dựa trên threshold
    binary_preds = (preds > threshold).astype(int)

    # Classification report
    report = classification_report(labels, binary_preds, target_names=['Class 0', 'Class 1'])
    print(report)

    # Tính AUC-ROC
    if len(set(labels)) > 1:  # Chỉ tính nếu có cả 2 lớp
        aucroc = roc_auc_score(labels, preds)
        print(f"AUC-ROC: {aucroc:.4f}")
    else:
        aucroc = None
        print("AUC-ROC: Undefined (only one class present in labels)")

    return report, aucroc

# Train Function
def train_detector(model, train_loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        y_pred = model(X_batch).squeeze()
        loss = criterion(y_pred, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)

# %%
dataset_path = r"D:\Study\Code\SwiftHydra\Classical\12_fault.npz"  # Replace with your dataset path
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load Data
X, y = load_adbench_data(dataset_path)

# Chia dữ liệu gốc trước khi áp dụng SMOTE
X_train, X_test, y_train, y_test = train_test_split(X.numpy(), y.numpy(), test_size=0.2, random_state=42, stratify=y)


# Handle Imbalanced Data with SMOTE
smote = SMOTE()

# Áp dụng SMOTE chỉ cho tập huấn luyện
X_resampled, y_resampled = smote.fit_resample(X_train, y_train)
# Chuyển lại thành tensor
X_train = torch.tensor(X_resampled, dtype=torch.float32)
y_train = torch.tensor(y_resampled, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# Kiểm tra phân phối
unique, counts = np.unique(y_train, return_counts=True)
print(f"Class distribution of training set after SMOTE: {dict(zip(unique, counts))}")

unique, counts = np.unique(y_test, return_counts=True)
print(f"Class distribution of testing set: {dict(zip(unique, counts))}")
# Create DataLoaders
train_dataset = TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64)
# Out:
# Class distribution of training set after SMOTE: {0.0: 1014, 1.0: 1014}
# Class distribution of testing set: {0.0: 254, 1.0: 135}

# %%
# Initialize Model
model = TransformerDetector(input_size=X.shape[1]).to(device)
optimizer = Adam(model.parameters(), lr=1e-3)
criterion = nn.BCELoss()

# Train and Evaluate
num_epochs = 200
for epoch in range(num_epochs):
    train_loss = train_detector(model, train_loader, optimizer, criterion, device)
    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {train_loss:.4f}")
    
    # Evaluate with classification report
    print("Classification Report on Test Set:")
    evaluate_with_classification_report_and_auc(model, test_loader, device)
# Out:
# Epoch 1/200, Loss: 0.5920
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.90      0.36      0.51       254
#      Class 1       0.43      0.93      0.59       135
#
#     accuracy                           0.56       389
#    macro avg       0.67      0.64      0.55       389
# weighted avg       0.74      0.56      0.54       389
#
# AUC-ROC: 0.7587
# Epoch 2/200, Loss: 0.5200
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.69      0.74       254
#      Class 1       0.54      0.67      0.60       135
#
#     accuracy                           0.69       389
#    macro avg       0.67      0.68      0.67       389
# weighted avg       0.71      0.69      0.69       389
#
# AUC-ROC: 0.7909
# Epoch 3/200, Loss: 0.4814
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.85      0.70      0.76       254
#      Class 1       0.57      0.76      0.65       135
#
#     accuracy                           0.72       389
#    macro avg       0.71      0.73      0.71       389
# weighted avg       0.75      0.72      0.73       389
#
# AUC-ROC: 0.8018
# Epoch 4/200, Loss: 0.4780
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.80      0.80       254
#      Class 1       0.62      0.61      0.62       135
#
#     accuracy                           0.74       389
#    macro avg       0.71      0.71      0.71       389
# weighted avg       0.74      0.74      0.74       389
#
# AUC-ROC: 0.8061
# Epoch 5/200, Loss: 0.4667
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.70      0.76       254
#      Class 1       0.56      0.71      0.63       135
#
#     accuracy                           0.70       389
#    macro avg       0.69      0.71      0.69       389
# weighted avg       0.73      0.70      0.71       389
#
# AUC-ROC: 0.7925
# Epoch 6/200, Loss: 0.4341
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.84      0.66      0.74       254
#      Class 1       0.54      0.77      0.64       135
#
#     accuracy                           0.70       389
#    macro avg       0.69      0.71      0.69       389
# weighted avg       0.74      0.70      0.70       389
#
# AUC-ROC: 0.8078
# Epoch 7/200, Loss: 0.4156
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.84      0.69      0.76       254
#      Class 1       0.56      0.75      0.64       135
#
#     accuracy                           0.71       389
#    macro avg       0.70      0.72      0.70       389
# weighted avg       0.74      0.71      0.72       389
#
# AUC-ROC: 0.8001
# Epoch 8/200, Loss: 0.4105
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.78      0.79       254
#      Class 1       0.61      0.65      0.63       135
#
#     accuracy                           0.73       389
#    macro avg       0.71      0.71      0.71       389
# weighted avg       0.74      0.73      0.73       389
#
# AUC-ROC: 0.8201
# Epoch 9/200, Loss: 0.3986
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.78      0.87      0.82       254
#      Class 1       0.69      0.53      0.60       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.70      0.71       389
# weighted avg       0.75      0.76      0.75       389
#
# AUC-ROC: 0.8187
# Epoch 10/200, Loss: 0.3985
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.77      0.82      0.79       254
#      Class 1       0.62      0.53      0.57       135
#
#     accuracy                           0.72       389
#    macro avg       0.69      0.68      0.68       389
# weighted avg       0.72      0.72      0.72       389
#
# AUC-ROC: 0.7954
# Epoch 11/200, Loss: 0.3729
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.75      0.78       254
#      Class 1       0.59      0.68      0.63       135
#
#     accuracy                           0.73       389
#    macro avg       0.70      0.72      0.71       389
# weighted avg       0.74      0.73      0.73       389
#
# AUC-ROC: 0.8290
# Epoch 12/200, Loss: 0.3641
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.74      0.78       254
#      Class 1       0.59      0.71      0.64       135
#
#     accuracy                           0.73       389
#    macro avg       0.71      0.72      0.71       389
# weighted avg       0.74      0.73      0.73       389
#
# AUC-ROC: 0.8302
# Epoch 13/200, Loss: 0.3489
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.79      0.87      0.82       254
#      Class 1       0.69      0.56      0.61       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.71      0.72       389
# weighted avg       0.75      0.76      0.75       389
#
# AUC-ROC: 0.8143
# Epoch 14/200, Loss: 0.3500
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.84      0.76      0.80       254
#      Class 1       0.62      0.73      0.67       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.75      0.74       389
# weighted avg       0.77      0.75      0.75       389
#
# AUC-ROC: 0.8309
# Epoch 15/200, Loss: 0.3380
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.73      0.77       254
#      Class 1       0.58      0.70      0.63       135
#
#     accuracy                           0.72       389
#    macro avg       0.70      0.71      0.70       389
# weighted avg       0.74      0.72      0.72       389
#
# AUC-ROC: 0.8173
# Epoch 16/200, Loss: 0.3400
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.83      0.82       254
#      Class 1       0.66      0.64      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8188
# Epoch 17/200, Loss: 0.3229
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.76      0.79       254
#      Class 1       0.61      0.70      0.65       135
#
#     accuracy                           0.74       389
#    macro avg       0.72      0.73      0.72       389
# weighted avg       0.75      0.74      0.74       389
#
# AUC-ROC: 0.8242
# Epoch 18/200, Loss: 0.3114
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.77      0.80       254
#      Class 1       0.62      0.71      0.66       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.74      0.73       389
# weighted avg       0.76      0.75      0.75       389
#
# AUC-ROC: 0.8384
# Epoch 19/200, Loss: 0.3051
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.83      0.82       254
#      Class 1       0.66      0.62      0.64       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8334
# Epoch 20/200, Loss: 0.2834
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.78      0.87      0.82       254
#      Class 1       0.69      0.55      0.61       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.71      0.72       389
# weighted avg       0.75      0.76      0.75       389
#
# AUC-ROC: 0.8325
# Epoch 21/200, Loss: 0.2920
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.83      0.83       254
#      Class 1       0.68      0.67      0.67       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.75      0.75       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8384
# Epoch 22/200, Loss: 0.2694
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.80      0.80       254
#      Class 1       0.63      0.64      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8360
# Epoch 23/200, Loss: 0.2810
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.85      0.83       254
#      Class 1       0.69      0.61      0.65       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.73      0.74       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8322
# Epoch 24/200, Loss: 0.2653
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.79      0.81       254
#      Class 1       0.64      0.70      0.67       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.75      0.74       389
# weighted avg       0.77      0.76      0.76       389
#
# AUC-ROC: 0.8265
# Epoch 25/200, Loss: 0.2574
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.81      0.81       254
#      Class 1       0.65      0.65      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8170
# Epoch 26/200, Loss: 0.2691
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.87      0.83       254
#      Class 1       0.70      0.59      0.64       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.73      0.73       389
# weighted avg       0.76      0.77      0.76       389
#
# AUC-ROC: 0.8360
# Epoch 27/200, Loss: 0.2696
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.80      0.81       254
#      Class 1       0.65      0.70      0.67       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.75      0.74       389
# weighted avg       0.77      0.76      0.77       389
#
# AUC-ROC: 0.8310
# Epoch 28/200, Loss: 0.2365
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.84      0.77      0.80       254
#      Class 1       0.63      0.72      0.67       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.75      0.74       389
# weighted avg       0.76      0.75      0.76       389
#
# AUC-ROC: 0.8344
# Epoch 29/200, Loss: 0.2322
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.84      0.78      0.81       254
#      Class 1       0.63      0.72      0.67       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.75      0.74       389
# weighted avg       0.77      0.76      0.76       389
#
# AUC-ROC: 0.8311
# Epoch 30/200, Loss: 0.2193
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.81      0.81       254
#      Class 1       0.64      0.63      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8244
# Epoch 31/200, Loss: 0.2206
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.81      0.81       254
#      Class 1       0.64      0.64      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8286
# Epoch 32/200, Loss: 0.2288
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.83      0.82       254
#      Class 1       0.66      0.62      0.64       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.72      0.73       389
# weighted avg       0.75      0.76      0.75       389
#
# AUC-ROC: 0.8431
# Epoch 33/200, Loss: 0.2108
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.80      0.80       254
#      Class 1       0.63      0.66      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.73      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8226
# Epoch 34/200, Loss: 0.2272
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.79      0.80       254
#      Class 1       0.62      0.67      0.65       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.73      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8178
# Epoch 35/200, Loss: 0.2010
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.78      0.80       254
#      Class 1       0.61      0.66      0.64       135
#
#     accuracy                           0.74       389
#    macro avg       0.71      0.72      0.72       389
# weighted avg       0.74      0.74      0.74       389
#
# AUC-ROC: 0.8204
# Epoch 36/200, Loss: 0.1962
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.80      0.81       254
#      Class 1       0.64      0.67      0.66       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.74      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8323
# Epoch 37/200, Loss: 0.1743
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.84      0.78      0.81       254
#      Class 1       0.64      0.71      0.67       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.75      0.74       389
# weighted avg       0.77      0.76      0.76       389
#
# AUC-ROC: 0.8311
# Epoch 38/200, Loss: 0.1813
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.76      0.79       254
#      Class 1       0.61      0.71      0.66       135
#
#     accuracy                           0.74       389
#    macro avg       0.72      0.74      0.73       389
# weighted avg       0.76      0.74      0.75       389
#
# AUC-ROC: 0.8255
# Epoch 39/200, Loss: 0.1698
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.81      0.80       254
#      Class 1       0.63      0.61      0.62       135
#
#     accuracy                           0.74       389
#    macro avg       0.71      0.71      0.71       389
# weighted avg       0.74      0.74      0.74       389
#
# AUC-ROC: 0.8273
# Epoch 40/200, Loss: 0.1870
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.82      0.82       254
#      Class 1       0.66      0.65      0.66       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8271
# Epoch 41/200, Loss: 0.1706
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.83      0.82       254
#      Class 1       0.66      0.63      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8237
# Epoch 42/200, Loss: 0.1581
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.78      0.80       254
#      Class 1       0.61      0.67      0.64       135
#
#     accuracy                           0.74       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.75      0.74      0.74       389
#
# AUC-ROC: 0.8043
# Epoch 43/200, Loss: 0.1591
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.86      0.83       254
#      Class 1       0.70      0.62      0.66       135
#
#     accuracy                           0.78       389
#    macro avg       0.76      0.74      0.75       389
# weighted avg       0.77      0.78      0.77       389
#
# AUC-ROC: 0.8314
# Epoch 44/200, Loss: 0.1870
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.80      0.81       254
#      Class 1       0.64      0.67      0.65       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.75      0.75       389
#
# AUC-ROC: 0.8402
# Epoch 45/200, Loss: 0.1418
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.81      0.82       254
#      Class 1       0.66      0.67      0.67       135
#
#     accuracy                           0.77       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8363
# Epoch 46/200, Loss: 0.1270
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.79      0.83      0.81       254
#      Class 1       0.66      0.59      0.62       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.71      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8160
# Epoch 47/200, Loss: 0.1297
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.79      0.81       254
#      Class 1       0.64      0.69      0.66       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.74      0.74       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8382
# Epoch 48/200, Loss: 0.1537
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.82      0.82       254
#      Class 1       0.66      0.65      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8418
# Epoch 49/200, Loss: 0.1283
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.83      0.81       254
#      Class 1       0.65      0.61      0.63       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.72      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8286
# Epoch 50/200, Loss: 0.1412
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.81      0.82       254
#      Class 1       0.65      0.67      0.66       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8236
# Epoch 51/200, Loss: 0.1437
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.79      0.83      0.81       254
#      Class 1       0.65      0.59      0.61       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.71      0.71       389
# weighted avg       0.74      0.75      0.74       389
#
# AUC-ROC: 0.8152
# Epoch 52/200, Loss: 0.1641
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.78      0.82      0.80       254
#      Class 1       0.63      0.57      0.60       135
#
#     accuracy                           0.74       389
#    macro avg       0.71      0.70      0.70       389
# weighted avg       0.73      0.74      0.73       389
#
# AUC-ROC: 0.8067
# Epoch 53/200, Loss: 0.1210
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.84      0.81      0.82       254
#      Class 1       0.66      0.71      0.69       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.76      0.75       389
# weighted avg       0.78      0.77      0.78       389
#
# AUC-ROC: 0.8351
# Epoch 54/200, Loss: 0.1111
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.80      0.80       254
#      Class 1       0.63      0.64      0.64       135
#
#     accuracy                           0.74       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.74      0.74      0.74       389
#
# AUC-ROC: 0.8235
# Epoch 55/200, Loss: 0.1018
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.78      0.80       254
#      Class 1       0.63      0.70      0.66       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.74      0.73       389
# weighted avg       0.76      0.75      0.76       389
#
# AUC-ROC: 0.8225
# Epoch 56/200, Loss: 0.1385
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.82      0.81       254
#      Class 1       0.65      0.64      0.64       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.75      0.76      0.76       389
#
# AUC-ROC: 0.8241
# Epoch 57/200, Loss: 0.1153
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.78      0.80       254
#      Class 1       0.62      0.66      0.64       135
#
#     accuracy                           0.74       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.74      0.74      0.74       389
#
# AUC-ROC: 0.8073
# Epoch 58/200, Loss: 0.1070
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.81      0.81       254
#      Class 1       0.64      0.63      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8214
# Epoch 59/200, Loss: 0.1103
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.81      0.80       254
#      Class 1       0.63      0.62      0.63       135
#
#     accuracy                           0.74       389
#    macro avg       0.72      0.71      0.72       389
# weighted avg       0.74      0.74      0.74       389
#
# AUC-ROC: 0.8008
# Epoch 60/200, Loss: 0.1190
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.82      0.82       254
#      Class 1       0.66      0.65      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8130
# Epoch 61/200, Loss: 0.1159
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.79      0.81       254
#      Class 1       0.64      0.70      0.66       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.74      0.74       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8383
# Epoch 62/200, Loss: 0.1054
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.79      0.81       254
#      Class 1       0.63      0.69      0.66       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.74      0.73       389
# weighted avg       0.76      0.75      0.76       389
#
# AUC-ROC: 0.8393
# Epoch 63/200, Loss: 0.0789
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.83      0.81       254
#      Class 1       0.66      0.61      0.63       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.72      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8167
# Epoch 64/200, Loss: 0.0758
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.85      0.80      0.82       254
#      Class 1       0.65      0.73      0.69       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.76      0.75       389
# weighted avg       0.78      0.77      0.77       389
#
# AUC-ROC: 0.8416
# Epoch 65/200, Loss: 0.0780
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.80      0.81       254
#      Class 1       0.65      0.69      0.67       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.77      0.76      0.76       389
#
# AUC-ROC: 0.8313
# Epoch 66/200, Loss: 0.0911
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.79      0.80       254
#      Class 1       0.62      0.66      0.64       135
#
#     accuracy                           0.74       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.75      0.74      0.74       389
#
# AUC-ROC: 0.8262
# Epoch 67/200, Loss: 0.1000
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.80      0.80       254
#      Class 1       0.63      0.66      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.73      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8135
# Epoch 68/200, Loss: 0.1049
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.81      0.81       254
#      Class 1       0.64      0.66      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8008
# Epoch 69/200, Loss: 0.1055
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.79      0.80       254
#      Class 1       0.63      0.67      0.65       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.73      0.73       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.7984
# Epoch 70/200, Loss: 0.1018
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.79      0.81      0.80       254
#      Class 1       0.63      0.60      0.62       135
#
#     accuracy                           0.74       389
#    macro avg       0.71      0.71      0.71       389
# weighted avg       0.74      0.74      0.74       389
#
# AUC-ROC: 0.8130
# Epoch 71/200, Loss: 0.0870
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.86      0.83       254
#      Class 1       0.70      0.62      0.66       135
#
#     accuracy                           0.78       389
#    macro avg       0.76      0.74      0.75       389
# weighted avg       0.77      0.78      0.77       389
#
# AUC-ROC: 0.7840
# Epoch 72/200, Loss: 0.0914
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.83      0.82       254
#      Class 1       0.66      0.63      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8164
# Epoch 73/200, Loss: 0.1054
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.81      0.82       254
#      Class 1       0.66      0.67      0.67       135
#
#     accuracy                           0.77       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8301
# Epoch 74/200, Loss: 0.0831
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.83      0.82       254
#      Class 1       0.66      0.63      0.64       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8340
# Epoch 75/200, Loss: 0.0746
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.83      0.83       254
#      Class 1       0.67      0.66      0.67       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.74      0.75       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8241
# Epoch 76/200, Loss: 0.0981
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.81      0.82       254
#      Class 1       0.66      0.69      0.68       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.75      0.75       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8290
# Epoch 77/200, Loss: 0.0718
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.82      0.82       254
#      Class 1       0.66      0.67      0.67       135
#
#     accuracy                           0.77       389
#    macro avg       0.74      0.75      0.75       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8206
# Epoch 78/200, Loss: 0.0670
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.82      0.81       254
#      Class 1       0.65      0.63      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.72      0.73       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8280
# Epoch 79/200, Loss: 0.0537
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.81      0.81       254
#      Class 1       0.65      0.64      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.7998
# Epoch 80/200, Loss: 0.0706
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.83      0.82       254
#      Class 1       0.66      0.63      0.64       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8086
# Epoch 81/200, Loss: 0.0743
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.84      0.82       254
#      Class 1       0.68      0.62      0.65       135
#
#     accuracy                           0.77       389
#    macro avg       0.74      0.73      0.74       389
# weighted avg       0.76      0.77      0.76       389
#
# AUC-ROC: 0.8308
# Epoch 82/200, Loss: 0.0533
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.80      0.81       254
#      Class 1       0.64      0.66      0.65       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.75      0.75       389
#
# AUC-ROC: 0.8072
# Epoch 83/200, Loss: 0.0844
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.81      0.81       254
#      Class 1       0.63      0.63      0.63       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8120
# Epoch 84/200, Loss: 0.0769
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.78      0.80       254
#      Class 1       0.63      0.69      0.66       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.74      0.73       389
# weighted avg       0.76      0.75      0.75       389
#
# AUC-ROC: 0.8288
# Epoch 85/200, Loss: 0.0747
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.81      0.81       254
#      Class 1       0.64      0.64      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.73      0.73       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8017
# Epoch 86/200, Loss: 0.0944
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.80      0.81       254
#      Class 1       0.64      0.67      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8091
# Epoch 87/200, Loss: 0.0872
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.79      0.81       254
#      Class 1       0.64      0.70      0.67       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.75      0.74       389
# weighted avg       0.77      0.76      0.76       389
#
# AUC-ROC: 0.8168
# Epoch 88/200, Loss: 0.0575
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.81      0.81       254
#      Class 1       0.64      0.66      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8201
# Epoch 89/200, Loss: 0.0500
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.80      0.82       254
#      Class 1       0.65      0.69      0.67       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.75      0.74       389
# weighted avg       0.77      0.76      0.77       389
#
# AUC-ROC: 0.8120
# Epoch 90/200, Loss: 0.0542
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.83      0.83       254
#      Class 1       0.67      0.66      0.67       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.74      0.75       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.7986
# Epoch 91/200, Loss: 0.0577
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.82      0.82       254
#      Class 1       0.66      0.67      0.66       135
#
#     accuracy                           0.77       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8128
# Epoch 92/200, Loss: 0.0672
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.81      0.81       254
#      Class 1       0.65      0.66      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.74      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8065
# Epoch 93/200, Loss: 0.0544
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.82      0.82       254
#      Class 1       0.66      0.64      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8142
# Epoch 94/200, Loss: 0.0521
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.81      0.81       254
#      Class 1       0.65      0.64      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8156
# Epoch 95/200, Loss: 0.0527
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.82      0.81       254
#      Class 1       0.65      0.62      0.63       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8184
# Epoch 96/200, Loss: 0.0484
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.82      0.82       254
#      Class 1       0.65      0.64      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.7823
# Epoch 97/200, Loss: 0.0756
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.85      0.82       254
#      Class 1       0.68      0.61      0.64       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.7857
# Epoch 98/200, Loss: 0.0888
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.81      0.82       254
#      Class 1       0.65      0.67      0.66       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8068
# Epoch 99/200, Loss: 0.0603
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.81      0.81       254
#      Class 1       0.65      0.65      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8296
# Epoch 100/200, Loss: 0.0713
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.82      0.81       254
#      Class 1       0.65      0.63      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.72      0.73       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8185
# Epoch 101/200, Loss: 0.0692
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.78      0.80       254
#      Class 1       0.63      0.69      0.66       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.74      0.73       389
# weighted avg       0.76      0.75      0.75       389
#
# AUC-ROC: 0.8061
# Epoch 102/200, Loss: 0.0571
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.81      0.81       254
#      Class 1       0.63      0.63      0.63       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8245
# Epoch 103/200, Loss: 0.0688
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.81      0.81       254
#      Class 1       0.64      0.63      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.7917
# Epoch 104/200, Loss: 0.0602
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.82      0.82       254
#      Class 1       0.66      0.67      0.67       135
#
#     accuracy                           0.77       389
#    macro avg       0.74      0.75      0.75       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8069
# Epoch 105/200, Loss: 0.0705
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.86      0.83       254
#      Class 1       0.70      0.59      0.64       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.73      0.73       389
# weighted avg       0.76      0.77      0.76       389
#
# AUC-ROC: 0.7949
# Epoch 106/200, Loss: 0.0486
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.83      0.82       254
#      Class 1       0.67      0.64      0.65       135
#
#     accuracy                           0.77       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.76      0.77      0.76       389
#
# AUC-ROC: 0.8272
# Epoch 107/200, Loss: 0.0499
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.82      0.82       254
#      Class 1       0.66      0.65      0.66       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8261
# Epoch 108/200, Loss: 0.0628
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.79      0.83      0.81       254
#      Class 1       0.64      0.59      0.61       135
#
#     accuracy                           0.74       389
#    macro avg       0.72      0.71      0.71       389
# weighted avg       0.74      0.74      0.74       389
#
# AUC-ROC: 0.7941
# Epoch 109/200, Loss: 0.0567
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.84      0.82       254
#      Class 1       0.67      0.62      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8156
# Epoch 110/200, Loss: 0.0646
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.80      0.81       254
#      Class 1       0.64      0.65      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8175
# Epoch 111/200, Loss: 0.0404
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.83      0.83       254
#      Class 1       0.68      0.65      0.66       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.74      0.75       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8126
# Epoch 112/200, Loss: 0.0345
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.83      0.82       254
#      Class 1       0.66      0.63      0.64       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.7875
# Epoch 113/200, Loss: 0.0403
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.79      0.81      0.80       254
#      Class 1       0.62      0.60      0.61       135
#
#     accuracy                           0.74       389
#    macro avg       0.71      0.70      0.71       389
# weighted avg       0.73      0.74      0.73       389
#
# AUC-ROC: 0.8174
# Epoch 114/200, Loss: 0.0413
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.80      0.80       254
#      Class 1       0.62      0.63      0.63       135
#
#     accuracy                           0.74       389
#    macro avg       0.71      0.71      0.71       389
# weighted avg       0.74      0.74      0.74       389
#
# AUC-ROC: 0.8129
# Epoch 115/200, Loss: 0.0380
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.84      0.83       254
#      Class 1       0.68      0.64      0.66       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.74      0.74       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8230
# Epoch 116/200, Loss: 0.0406
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.82      0.82       254
#      Class 1       0.66      0.66      0.66       135
#
#     accuracy                           0.77       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8313
# Epoch 117/200, Loss: 0.0497
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.81      0.82       254
#      Class 1       0.65      0.66      0.66       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8083
# Epoch 118/200, Loss: 0.0641
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.79      0.81       254
#      Class 1       0.64      0.70      0.67       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.7963
# Epoch 119/200, Loss: 0.0786
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.81      0.80       254
# ...
#    macro avg       0.73      0.72      0.73       389
# weighted avg       0.75      0.76      0.76       389
#
# AUC-ROC: 0.8147
# Epoch 162/200, Loss: 0.0582
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.86      0.83       254
#      Class 1       0.70      0.61      0.65       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.74      0.74       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8133
# Epoch 163/200, Loss: 0.0730
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.78      0.79       254
#      Class 1       0.61      0.65      0.63       135
#
#     accuracy                           0.74       389
#    macro avg       0.71      0.72      0.71       389
# weighted avg       0.74      0.74      0.74       389
#
# AUC-ROC: 0.7866
# Epoch 164/200, Loss: 0.0564
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.81      0.82       254
#      Class 1       0.65      0.67      0.66       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8194
# Epoch 165/200, Loss: 0.0525
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.78      0.85      0.81       254
#      Class 1       0.66      0.56      0.61       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.70      0.71       389
# weighted avg       0.74      0.75      0.74       389
#
# AUC-ROC: 0.8031
# Epoch 166/200, Loss: 0.0371
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.80      0.81       254
#      Class 1       0.64      0.70      0.67       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.75      0.74       389
# weighted avg       0.77      0.76      0.76       389
#
# AUC-ROC: 0.8053
# Epoch 167/200, Loss: 0.0273
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.83      0.82       254
#      Class 1       0.67      0.64      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.73      0.74       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8083
# Epoch 168/200, Loss: 0.0294
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.80      0.81       254
#      Class 1       0.64      0.67      0.65       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.75      0.75       389
#
# AUC-ROC: 0.8030
# Epoch 169/200, Loss: 0.0400
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.84      0.83       254
#      Class 1       0.68      0.63      0.65       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.74      0.74       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8092
# Epoch 170/200, Loss: 0.0412
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.82      0.81       254
#      Class 1       0.65      0.63      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.72      0.73       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8147
# Epoch 171/200, Loss: 0.0552
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.82      0.82       254
#      Class 1       0.66      0.65      0.66       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8195
# Epoch 172/200, Loss: 0.0471
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.83      0.83       254
#      Class 1       0.68      0.66      0.67       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.75      0.75       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8444
# Epoch 173/200, Loss: 0.0617
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.82      0.82       254
#      Class 1       0.66      0.67      0.66       135
#
#     accuracy                           0.77       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8173
# Epoch 174/200, Loss: 0.0405
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.81      0.81       254
#      Class 1       0.64      0.65      0.65       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8194
# Epoch 175/200, Loss: 0.0231
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.80      0.82       254
#      Class 1       0.65      0.70      0.67       135
#
#     accuracy                           0.77       389
#    macro avg       0.74      0.75      0.75       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8107
# Epoch 176/200, Loss: 0.0180
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.81      0.81       254
#      Class 1       0.63      0.63      0.63       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8189
# Epoch 177/200, Loss: 0.0182
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.81      0.82       254
#      Class 1       0.66      0.70      0.68       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.75      0.75       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8118
# Epoch 178/200, Loss: 0.0280
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.81      0.80       254
#      Class 1       0.63      0.62      0.63       135
#
#     accuracy                           0.74       389
#    macro avg       0.72      0.71      0.72       389
# weighted avg       0.74      0.74      0.74       389
#
# AUC-ROC: 0.8163
# Epoch 179/200, Loss: 0.0419
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.83      0.83       254
#      Class 1       0.68      0.67      0.67       135
#
#     accuracy                           0.78       389
#    macro avg       0.75      0.75      0.75       389
# weighted avg       0.78      0.78      0.78       389
#
# AUC-ROC: 0.8199
# Epoch 180/200, Loss: 0.0300
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.84      0.82       254
#      Class 1       0.67      0.61      0.64       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.72      0.73       389
# weighted avg       0.75      0.76      0.76       389
#
# AUC-ROC: 0.8082
# Epoch 181/200, Loss: 0.0299
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.81      0.80       254
#      Class 1       0.63      0.62      0.63       135
#
#     accuracy                           0.74       389
#    macro avg       0.72      0.71      0.72       389
# weighted avg       0.74      0.74      0.74       389
#
# AUC-ROC: 0.7916
# Epoch 182/200, Loss: 0.0323
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.80      0.81       254
#      Class 1       0.64      0.67      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8263
# Epoch 183/200, Loss: 0.0564
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.78      0.86      0.82       254
#      Class 1       0.67      0.54      0.60       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.70      0.71       389
# weighted avg       0.74      0.75      0.74       389
#
# AUC-ROC: 0.8071
# Epoch 184/200, Loss: 0.0376
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.79      0.83      0.81       254
#      Class 1       0.65      0.59      0.62       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.71      0.72       389
# weighted avg       0.74      0.75      0.75       389
#
# AUC-ROC: 0.8091
# Epoch 185/200, Loss: 0.0244
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.84      0.83       254
#      Class 1       0.69      0.65      0.67       135
#
#     accuracy                           0.78       389
#    macro avg       0.75      0.75      0.75       389
# weighted avg       0.77      0.78      0.77       389
#
# AUC-ROC: 0.8040
# Epoch 186/200, Loss: 0.0272
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.84      0.82       254
#      Class 1       0.67      0.62      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8084
# Epoch 187/200, Loss: 0.0291
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.82      0.82       254
#      Class 1       0.66      0.64      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8305
# Epoch 188/200, Loss: 0.0406
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.83      0.82       254
#      Class 1       0.66      0.62      0.64       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.72      0.73       389
# weighted avg       0.75      0.76      0.75       389
#
# AUC-ROC: 0.7940
# Epoch 189/200, Loss: 0.0570
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.85      0.83       254
#      Class 1       0.69      0.64      0.66       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.74      0.75       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8164
# Epoch 190/200, Loss: 0.0266
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.79      0.80      0.80       254
#      Class 1       0.62      0.60      0.61       135
#
#     accuracy                           0.73       389
#    macro avg       0.70      0.70      0.70       389
# weighted avg       0.73      0.73      0.73       389
#
# AUC-ROC: 0.8133
# Epoch 191/200, Loss: 0.0172
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.81      0.81       254
#      Class 1       0.64      0.64      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.73      0.73      0.73       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8355
# Epoch 192/200, Loss: 0.0212
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.80      0.80       254
#      Class 1       0.63      0.63      0.63       135
#
#     accuracy                           0.74       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.74      0.74      0.74       389
#
# AUC-ROC: 0.8015
# Epoch 193/200, Loss: 0.0284
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.80      0.83      0.82       254
#      Class 1       0.66      0.61      0.64       135
#
#     accuracy                           0.76       389
#    macro avg       0.73      0.72      0.73       389
# weighted avg       0.75      0.76      0.76       389
#
# AUC-ROC: 0.8006
# Epoch 194/200, Loss: 0.0668
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.79      0.83      0.81       254
#      Class 1       0.65      0.58      0.61       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.71      0.71       389
# weighted avg       0.74      0.75      0.74       389
#
# AUC-ROC: 0.7904
# Epoch 195/200, Loss: 0.0551
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.81      0.82       254
#      Class 1       0.66      0.69      0.68       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.75      0.75       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8213
# Epoch 196/200, Loss: 0.0448
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.81      0.82       254
#      Class 1       0.66      0.68      0.67       135
#
#     accuracy                           0.77       389
#    macro avg       0.74      0.75      0.75       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8264
# Epoch 197/200, Loss: 0.0383
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.85      0.83       254
#      Class 1       0.69      0.61      0.65       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.73      0.74       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8279
# Epoch 198/200, Loss: 0.0222
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.82      0.83      0.83       254
#      Class 1       0.67      0.67      0.67       135
#
#     accuracy                           0.77       389
#    macro avg       0.75      0.75      0.75       389
# weighted avg       0.77      0.77      0.77       389
#
# AUC-ROC: 0.8177
# Epoch 199/200, Loss: 0.0285
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.83      0.82       254
#      Class 1       0.66      0.64      0.65       135
#
#     accuracy                           0.76       389
#    macro avg       0.74      0.74      0.74       389
# weighted avg       0.76      0.76      0.76       389
#
# AUC-ROC: 0.8172
# Epoch 200/200, Loss: 0.0388
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#      Class 0       0.81      0.81      0.81       254
#      Class 1       0.64      0.63      0.64       135
#
#     accuracy                           0.75       389
#    macro avg       0.72      0.72      0.72       389
# weighted avg       0.75      0.75      0.75       389
#
# AUC-ROC: 0.8034
